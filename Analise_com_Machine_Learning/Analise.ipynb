# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\DataBases\Aula4_Intensive_Python\advertising.csv')
display(df)
# Out:
#         TV  Radio  Jornal  Vendas
# 0    230.1   37.8    69.2    22.1
# 1     44.5   39.3    45.1    10.4
# 2     17.2   45.9    69.3    12.0
# 3    151.5   41.3    58.5    16.5
# 4    180.8   10.8    58.4    17.9
# ..     ...    ...     ...     ...
# 195   38.2    3.7    13.8     7.6
# 196   94.2    4.9     8.1    14.0
# 197  177.0    9.3     6.4    14.8
# 198  283.6   42.0    66.2    25.5
# 199  232.1    8.6     8.7    18.4
#
# [200 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df.corr(), cmap="Wistia", annot=True)

plt.show()

# %% [markdown]
# MONTANDO MACHINE LEARNING

# %%
y = df['Vendas']
x = df[['TV','Radio', 'Jornal']]
from sklearn.model_selection import train_test_split

# %%
x_treino, x_teste,  y_treino, y_teste = train_test_split(x,y)

#x_treino, y_treino, x_teste, y_teste = train_test_split(x,y, test_size=0.3)
#divide a base de dados em 70% treino e 30% teste

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
#criar modelo regressao linear
modelo_regressaolinear = LinearRegression()

#criar modelo arvore de decisao
modelo_arvoredecisao = RandomForestRegressor()

# %%
#treinar modelo regressao linear
modelo_regressaolinear.fit(x_treino, y_treino)
modelo_arvoredecisao.fit(x_treino, y_treino)
# Out:
# RandomForestRegressor()

# %%
#testando modelo regressao linear
previsao_regressaolinear = modelo_regressaolinear.predict(x_teste)
#testando modelo arvore de decisao
previsao_modelodecisao = modelo_arvoredecisao.predict(x_teste)

# %%
from sklearn import metrics

print(metrics.r2_score(y_teste, previsao_regressaolinear))
print(metrics.r2_score(y_teste, previsao_modelodecisao))
# Out:
# 0.8974195669377215
# 0.9409474177328153

# %%
tabela = pd.DataFrame()

tabela["y_teste"] = y_teste

tabela["Previsao Regressão Linear"] = previsao_regressaolinear
tabela["Previsao Modelo Decisão"] = previsao_modelodecisao


plt.figure(figsize=(15,6))
sns.lineplot(data=tabela)
plt.show()

# %% [markdown]
# Fazendo uma previsão

# %%
df_prev = pd.read_csv(r'C:\DataBases\Aula4_Intensive_Python\novos.csv')
display(df_prev)
# Out:
#       TV  Radio  Jornal
# 0   23.1    3.8    69.2
# 1   44.5    0.0     5.1
# 2  170.2   45.9     0.0

# %%
nova_previsao=modelo_arvoredecisao.predict(df_prev)
print(nova_previsao)
# Out:
# [ 7.371  8.662 20.325]
